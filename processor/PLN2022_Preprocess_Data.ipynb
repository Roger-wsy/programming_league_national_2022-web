# %%
import pandas as pd

# %%
df = pd.read_csv("/content/pln.csv")
df.head()
# Out:
#             Timestamp                  Team Name Open or Closed Category?  \
# 0  2/21/2022 14:40:25  3.5 Years IT Chicken Rice            Open Category
# 1  2/21/2022 15:36:36               RookieCoders          Closed Category
# 2  2/21/2022 16:22:24    PizzaWithPineapple(PWP)            Open Category
# 3  2/21/2022 16:47:40            2 Blue 1 Violet            Open Category
# 4  2/21/2022 16:53:36                        ABC          Closed Category
#
#   Full Name (CAPITAL LETTERS)  Gender Date of Birth  \
# 0                YAP GAY CHIN    Male    12/27/1999
# 1              TAN GENG CHENG    Male      2/2/2002
# 2               LIEW MAN HONG    Male     8/30/2000
# 3               LEE CHENG HUI    Male      8/4/2000
# 4                OOI JIA MING  Female     7/30/2002
#
#    Phone number (eg: +60123456789)                 Email Address  \
# 0                      60186693572           gcyap1227@gmail.com
# 1                      60103154771      u2102846@siswa.um.edu.my
# ...

# %%
# df.info()

# %%
df = df[[
  "Team Name",
  "Open or Closed Category?",
  "Full Name (CAPITAL LETTERS)",
  "Institute/University (CAPITAL LETTERS)",
  "Full Name (CAPITAL LETTERS).1",
  "Institute/University (CAPITAL LETTERS).1",
  "Full Name (CAPITAL LETTERS).2",
  "Institute/University (CAPITAL LETTERS).2"
]]
df = df.rename(columns={
  "Open or Closed Category?": "open",
  "Full Name (CAPITAL LETTERS)": "name1",
  "Institute/University (CAPITAL LETTERS)": "uni1",
  "Full Name (CAPITAL LETTERS).1": "name2",
  "Institute/University (CAPITAL LETTERS).1": "uni2",
  "Full Name (CAPITAL LETTERS).2": "name3",
  "Institute/University (CAPITAL LETTERS).2": "uni3"
})
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())
df.head()
# Out:
#                    Team Name             open           name1  \
# 0  3.5 Years IT Chicken Rice    Open Category    YAP GAY CHIN
# 1               RookieCoders  Closed Category  TAN GENG CHENG
# 2    PizzaWithPineapple(PWP)    Open Category   LIEW MAN HONG
# 3            2 Blue 1 Violet    Open Category   LEE CHENG HUI
# 4                        ABC  Closed Category    OOI JIA MING
#
#                         uni1                 name2                       uni2  \
# 0          UNIVERSITI MALAYA  DESMOND KANG YU HANG          UNIVERSITI MALAYA
# 1          UNIVERSITY MALAYA           XIAOXIAO WU          UNIVERSITY MALAYA
# 2  UNIVERSITI SAINS MALAYSIA   SHAUN LIEW XIN HONG  UNIVERSITI SAINS MALAYSIA
# 3          UNIVERSITI MALAYA     AMOS TAN LI SHENG          UNIVERSITY MALAYA
# 4          UNIVERSITI MALAYA             TAN ZI AN          UNIVERSITI MALAYA
#
#             name3                       uni3
# 0    TAN JAI SING          UNIVERSITI MALAYA
# ...

# %%
# df.to_json("pln.json", index=False, orient="split")
df
# Out:
#                      Team Name             open  \
# 0    3.5 Years IT Chicken Rice    Open Category
# 1                 RookieCoders  Closed Category
# 2      PizzaWithPineapple(PWP)    Open Category
# 3              2 Blue 1 Violet    Open Category
# 4                          ABC  Closed Category
# ..                         ...              ...
# 109               UTP-CODEZIAN    Open Category
# 110                       CmCz    Open Category
# 111                   Team LLY    Open Category
# 112                      pokok    Open Category
# 113             codingHamsters  Closed Category
#
#                                        name1                           uni1  \
# 0                               YAP GAY CHIN              UNIVERSITI MALAYA
# 1                             TAN GENG CHENG              UNIVERSITY MALAYA
# 2                              LIEW MAN HONG      UNIVERSITI SAINS MALAYSIA
# 3                              LEE CHENG HUI              UNIVERSITI MALAYA
# ...

# %%
df.loc[(df["uni1"] == "UNIVERSITI MALAYA") | (df["uni1"] == "UNIVERSITY MALAYA") | (df["uni1"] == "UNIVERISITI MALAYA") | (df["uni1"] == "UNIVERSITI MLAYA") | (df["uni1"] == "UNIVERSITY OF MALAYA"),'uni1']="UM"
df.loc[(df["uni2"] == "UNIVERSITI MALAYA") | (df["uni2"] == "UNIVERSITY MALAYA") | (df["uni2"] == "UNIVERISITI MALAYA") | (df["uni2"] == "UNIVERSITI MLAYA") | (df["uni2"] == "UNIVERSITY OF MALAYA"),'uni2']="UM"
df.loc[(df["uni3"] == "UNIVERSITI MALAYA") | (df["uni3"] == "UNIVERSITY MALAYA") | (df["uni3"] == "UNIVERISITI MALAYA") | (df["uni3"] == "UNIVERSITI MLAYA") | (df["uni3"] == "UNIVERSITY OF MALAYA"),'uni3']="UM"

df.loc[(df["uni1"] == "UNIVERSITI SAINS MALAYSIA"), 'uni1']="USM"
df.loc[(df["uni2"] == "UNIVERSITI SAINS MALAYSIA"), 'uni2']="USM"
df.loc[(df["uni3"] == "UNIVERSITI SAINS MALAYSIA"), 'uni3']="USM"

df.loc[(df["uni1"] == "UNIVERSITI MALAYSIA TERENGGANU") | (df["uni1"] == "UNIVERSITY MALAYSIA TERENGGANU"), 'uni1']="UMTERENGGANU"
df.loc[(df["uni2"] == "UNIVERSITI MALAYSIA TERENGGANU") | (df["uni2"] == "UNIVERSITY MALAYSIA TERENGGANU"), 'uni2']="UMTERENGGANU"
df.loc[(df["uni3"] == "UNIVERSITI MALAYSIA TERENGGANU") | (df["uni3"] == "UNIVERSITY MALAYSIA TERENGGANU"), 'uni3']="UMTERENGGANU"

df.loc[(df["uni1"] == "MONASH UNIVERSITY") | (df["uni1"] == "MONASH UNIVERSITY MALAYSIA"), 'uni1']="MONASH"
df.loc[(df["uni2"] == "MONASH UNIVERSITY") | (df["uni2"] == "MONASH UNIVERSITY MALAYSIA"), 'uni2']="MONASH"
df.loc[(df["uni3"] == "MONASH UNIVERSITY") | (df["uni3"] == "MONASH UNIVERSITY MALAYSIA"), 'uni3']="MONASH"

df.loc[(df["uni1"] == "UNIVERSITI TEKNOLOGI MALAYSIA") | (df["uni1"] == "UNIVERSITI TEKLONOGI MALAYSIA"), 'uni1']="UTM"
df.loc[(df["uni2"] == "UNIVERSITI TEKNOLOGI MALAYSIA") | (df["uni2"] == "UNIVERSITI TEKLONOGI MALAYSIA"), 'uni2']="UTM"
df.loc[(df["uni3"] == "UNIVERSITI TEKNOLOGI MALAYSIA") | (df["uni3"] == "UNIVERSITI TEKLONOGI MALAYSIA"), 'uni3']="UTM"

df.loc[(df["uni1"] == "INTI INTERNATIONAL COLLEGE PENANG"), 'uni1']="IICP"
df.loc[(df["uni2"] == "INTI INTERNATIONAL COLLEGE PENANG"), 'uni2']="IICP"
df.loc[(df["uni3"] == "INTI INTERNATIONAL COLLEGE PENANG"), 'uni3']="IICP"

df.loc[(df["uni1"] == "UNIVERSITI TUNKU ABDUL RAHMAN"), 'uni1']="UTAR"
df.loc[(df["uni2"] == "UNIVERSITI TUNKU ABDUL RAHMAN"), 'uni2']="UTAR"
df.loc[(df["uni3"] == "UNIVERSITI TUNKU ABDUL RAHMAN"), 'uni3']="UTAR"

df.loc[(df["uni1"] == "TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE"), 'uni1']="TARUC"
df.loc[(df["uni2"] == "TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE"), 'uni2']="TARUC"
df.loc[(df["uni3"] == "TUNKU ABDUL RAHMAN UNIVERSITY COLLEGE"), 'uni3']="TARUC"

df.loc[(df["uni1"] == "UNIVERSITI TEKNOLOGI MARA") | (df["uni1"] == "UNIVERISTI TEKNOLOGI MARA"), 'uni1']="UTMARA"
df.loc[(df["uni2"] == "UNIVERSITI TEKNOLOGI MARA") | (df["uni2"] == "UNIVERISTI TEKNOLOGI MARA"), 'uni2']="UTMARA"
df.loc[(df["uni3"] == "UNIVERSITI TEKNOLOGI MARA") | (df["uni3"] == "UNIVERISTI TEKNOLOGI MARA"), 'uni3']="UTMARA"

df.loc[(df["uni1"] == "POLYTECHNIC BALIK PULAU"), 'uni1']="PBP"
df.loc[(df["uni2"] == "POLYTECHNIC BALIK PULAU"), 'uni2']="PBP"
df.loc[(df["uni3"] == "POLYTECHNIC BALIK PULAU"), 'uni3']="PBP"

df.loc[(df["uni1"] == "UNIVERSITY SAINS MALAYSIA"), 'uni1']="USM"
df.loc[(df["uni2"] == "UNIVERSITY SAINS MALAYSIA"), 'uni2']="USM"
df.loc[(df["uni3"] == "UNIVERSITY SAINS MALAYSIA"), 'uni3']="USM"

df.loc[(df["uni1"] == "UNIVERSITI PUTRA MALAYSIA") | (df["uni1"] == "UNIVERISTI PUTRA MALAYSIA"), 'uni1']="UPM"
df.loc[(df["uni2"] == "UNIVERSITI PUTRA MALAYSIA") | (df["uni2"] == "UNIVERISTI PUTRA MALAYSIA"), 'uni2']="UPM"
df.loc[(df["uni3"] == "UNIVERSITI PUTRA MALAYSIA") | (df["uni3"] == "UNIVERISTI PUTRA MALAYSIA"), 'uni3']="UPM"

df.loc[(df["uni1"] == "UNIVERSITI KEBANGSAAN MALAYSIA") | (df["uni1"] == "UNIVERSITI KEBANGSAAN MALAYSIA (UKM)") | (df["uni1"] == "UNIVERTISI KEBANGSAAN MALAYSIA") | (df["uni1"] == "NATIONAL UNIVERSITY OF MALAYSIA (UKM)") | (df["uni1"] == "UNIVERSITY KEBANGSAAN MALAYSIA"), 'uni1']="UKM"
df.loc[(df["uni2"] == "UNIVERSITI KEBANGSAAN MALAYSIA") | (df["uni2"] == "UNIVERSITI KEBANGSAAN MALAYSIA (UKM)") | (df["uni2"] == "UNIVERTISI KEBANGSAAN MALAYSIA") | (df["uni2"] == "NATIONAL UNIVERSITY OF MALAYSIA (UKM)") | (df["uni2"] == "UNIVERSITY KEBANGSAAN MALAYSIA"), 'uni2']="UKM"
df.loc[(df["uni3"] == "UNIVERSITI KEBANGSAAN MALAYSIA") | (df["uni3"] == "UNIVERSITI KEBANGSAAN MALAYSIA (UKM)") | (df["uni3"] == "UNIVERTISI KEBANGSAAN MALAYSIA") | (df["uni3"] == "NATIONAL UNIVERSITY OF MALAYSIA (UKM)") | (df["uni3"] == "UNIVERSITY KEBANGSAAN MALAYSIA"), 'uni3']="UKM"

df.loc[(df["uni1"] == "UNIVERSITU OF NOTTINGHAM MALAYSIA") | (df["uni1"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA") | (df["uni1"] == "UNIVERISITY OF NOTTINGHAM MALAYSIA") | (df["uni1"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA CAMPUS") | (df["uni1"] == "UNVIERSITY OF NOTTINGHAM MALAYSIA"), 'uni1'] = "NOTTINGHAM"
df.loc[(df["uni2"] == "UNIVERSITU OF NOTTINGHAM MALAYSIA") | (df["uni2"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA") | (df["uni2"] == "UNIVERISITY OF NOTTINGHAM MALAYSIA") | (df["uni2"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA CAMPUS") | (df["uni2"] == "UNVIERSITY OF NOTTINGHAM MALAYSIA"), 'uni2'] = "NOTTINGHAM"
df.loc[(df["uni3"] == "UNIVERSITU OF NOTTINGHAM MALAYSIA") | (df["uni3"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA") | (df["uni3"] == "UNIVERISITY OF NOTTINGHAM MALAYSIA") | (df["uni3"] == "UNIVERSITY OF NOTTINGHAM MALAYSIA CAMPUS") | (df["uni3"] == "UNVIERSITY OF NOTTINGHAM MALAYSIA"), 'uni3'] = "NOTTINGHAM"

df.loc[(df["uni1"] == "ERICAN COLLEGE"), 'uni1']="ERICAN"
df.loc[(df["uni2"] == "ERICAN COLLEGE"), 'uni2']="ERICAN"
df.loc[(df["uni3"] == "ERICAN COLLEGE"), 'uni3']="ERICAN"

df.loc[(df["uni1"] == "UNIVERSITI SAINS ISLAM MALAYSIA") | (df["uni1"] == "UNIVERSITI SAINS ISLAM MALAYSIA (USIM)"), 'uni1']="USIM"
df.loc[(df["uni2"] == "UNIVERSITI SAINS ISLAM MALAYSIA") | (df["uni2"] == "UNIVERSITI SAINS ISLAM MALAYSIA (USIM)"), 'uni2']="USIM"
df.loc[(df["uni3"] == "UNIVERSITI SAINS ISLAM MALAYSIA") | (df["uni3"] == "UNIVERSITI SAINS ISLAM MALAYSIA (USIM)"), 'uni3']="USIM"

df.loc[(df["uni1"] == "TAYLOR'S UNIVERSITY"), 'uni1']="TAYLOR"
df.loc[(df["uni2"] == "TAYLOR'S UNIVERSITY"), 'uni2']="TAYLOR"
df.loc[(df["uni3"] == "TAYLOR'S UNIVERSITY"), 'uni3']="TAYLOR"

df.loc[(df["uni1"] == "NILAI UNIVERSITI") | (df["uni1"] == "NILAI UNIVERSITY"), 'uni1']="NILAI"
df.loc[(df["uni2"] == "NILAI UNIVERSITI") | (df["uni2"] == "NILAI UNIVERSITY"), 'uni2']="NILAI"
df.loc[(df["uni3"] == "NILAI UNIVERSITI") | (df["uni3"] == "NILAI UNIVERSITY"), 'uni3']="NILAI"

df.loc[(df["uni1"] == "UNIVERSITY TEKNIKAL MALAYSIA MELAKA") | (df["uni1"] == "UNIVERSITI TEKNIKAL MALAYSIA MELAKA"), 'uni1']="UTMMELAKA"
df.loc[(df["uni2"] == "UNIVERSITY TEKNIKAL MALAYSIA MELAKA") | (df["uni2"] == "UNIVERSITI TEKNIKAL MALAYSIA MELAKA"), 'uni2']="UTMMELAKA"
df.loc[(df["uni3"] == "UNIVERSITY TEKNIKAL MALAYSIA MELAKA") | (df["uni3"] == "UNIVERSITI TEKNIKAL MALAYSIA MELAKA"), 'uni3']="UTMMELAKA"

df.loc[(df["uni1"] == "MULTIMEDIA UNIVERSITY"), 'uni1']="MULTIMEDIA"
df.loc[(df["uni2"] == "MULTIMEDIA UNIVERSITY"), 'uni2']="MULTIMEDIA"
df.loc[(df["uni3"] == "MULTIMEDIA UNIVERSITY"), 'uni3']="MULTIMEDIA"

df.loc[(df["uni1"] == "MANAGEMENT & SCIENCE UNIVERSITY"), 'uni1']="MSU"
df.loc[(df["uni2"] == "MANAGEMENT & SCIENCE UNIVERSITY"), 'uni2']="MSU"
df.loc[(df["uni3"] == "MANAGEMENT & SCIENCE UNIVERSITY"), 'uni3']="MSU"

df.loc[(df["uni1"] == "ASIA PACIFIC UNIVERSITY"), 'uni1']="APU"
df.loc[(df["uni2"] == "ASIA PACIFIC UNIVERSITY"), 'uni2']="APU"
df.loc[(df["uni3"] == "ASIA PACIFIC UNIVERSITY"), 'uni3']="APU"

df.loc[(df["uni1"] == "UNIVERSITI TEKNOLOGI PETRONAS"), 'uni1']="UTP"
df.loc[(df["uni2"] == "UNIVERSITI TEKNOLOGI PETRONAS"), 'uni2']="UTP"
df.loc[(df["uni3"] == "UNIVERSITI TEKNOLOGI PETRONAS"), 'uni3']="UTP"

df.loc[(df["uni1"] == "UNIVERSITY MALAYSIA KELANTAN"), 'uni1']="UMKELANTAN"
df.loc[(df["uni2"] == "UNIVERSITY MALAYSIA KELANTAN"), 'uni2']="UMKELANTAN"
df.loc[(df["uni3"] == "UNIVERSITY MALAYSIA KELANTAN"), 'uni3']="UMKELANTAN"

df.loc[(df["uni1"] == "UNIVERSITY OF KUALA LUMPUR"), 'uni1']="UKL"
df.loc[(df["uni2"] == "UNIVERSITY OF KUALA LUMPUR"), 'uni2']="UKL"
df.loc[(df["uni3"] == "UNIVERSITY OF KUALA LUMPUR"), 'uni3']="UKL"

df.loc[(df["uni1"] == "UNIVERSITI MALAYSIA PAHANG") | (df["uni1"] == "UNIVERSITY MALAYSIA PAHANG"), 'uni1']="UMPAHANG"
df.loc[(df["uni2"] == "UNIVERSITI MALAYSIA PAHANG") | (df["uni2"] == "UNIVERSITY MALAYSIA PAHANG"), 'uni2']="UMPAHANG"
df.loc[(df["uni3"] == "UNIVERSITI MALAYSIA PAHANG") | (df["uni3"] == "UNIVERSITY MALAYSIA PAHANG"), 'uni3']="UMPAHANG"

df.loc[(df["uni1"] == "INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA"), 'uni1']="IIUM"
df.loc[(df["uni2"] == "INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA"), 'uni2']="IIUM"
df.loc[(df["uni3"] == "INTERNATIONAL ISLAMIC UNIVERSITY MALAYSIA"), 'uni3']="IIUM"

df.loc[(df["uni1"] == "UNIVERSITI MALAYSIA SARAWAK"), 'uni1']="UMSARAWAK"
df.loc[(df["uni2"] == "UNIVERSITI MALAYSIA SARAWAK"), 'uni2']="UMSARAWAK"
df.loc[(df["uni3"] == "UNIVERSITI MALAYSIA SARAWAK"), 'uni3']="UMSARAWAK"

df.loc[(df["uni1"] == "SWINBURNE UNIVERSITY"), 'uni1']="SWINBURNE"
df.loc[(df["uni2"] == "SWINBURNE UNIVERSITY"), 'uni2']="SWINBURNE"
df.loc[(df["uni3"] == "SWINBURNE UNIVERSITY"), 'uni3']="SWINBURNE"

df.loc[(df["uni1"] == "XIAMEN UNIVERSITY MALAYSIA"), 'uni1']="XIAMEN"
df.loc[(df["uni2"] == "XIAMEN UNIVERSITY MALAYSIA"), 'uni2']="XIAMEN"
df.loc[(df["uni3"] == "XIAMEN UNIVERSITY MALAYSIA"), 'uni3']="XIAMEN"

# %%
# df["uni1"].unique(), df["uni2"].unique(), df["uni3"].unique()

# %%
df.loc[(df["open"] == "Open Category"), 'open']="true"
df.loc[(df["open"] == "Closed Category"), 'open']="false"

# %%
# df.to_json("pln.json", index=False, orient="split")
df.to_json("pln.json", index=False, orient="table")

# %%
l = pd.unique(df[['uni1', 'uni2', 'uni3']].values.ravel('K'))

# %%
sorted(l)
# Out:
# ['APU',
#  'ERICAN',
#  'IICP',
#  'IIUM',
#  'MONASH',
#  'MSU',
#  'MULTIMEDIA',
#  'NILAI',
#  'NO',
#  'NOTTINGHAM',
#  'PBP',
#  'SWINBURNE',
#  'TARUC',
#  'TAYLOR',
#  'UCSI',
#  'UKL',
#  'UKM',
#  'UM',
#  'UMKELANTAN',
#  'UMPAHANG',
#  'UMSARAWAK',
#  'UMTERENGGANU',
#  'UNITEN',
#  'UPM',
#  'USIM',
#  'USM',
#  'UTAR',
#  'UTM',
#  'UTMARA',
#  'UTMMELAKA',
#  'UTP',
#  'XIAMEN']

# %%
df.loc[df["open"] == "false"]
# Out:
#                         Team Name   open  \
# 1                    RookieCoders  false
# 4                             ABC  false
# 9                             A²I  false
# 12           Hokkien Mee is Black  false
# 13              Programming Noobs  false
# 14                           Rawr  false
# 16                            NGT  false
# 18                           RiOz  false
# 20                  Quackalicious  false
# 22   United Spirits of Malaysians  false
# 24                      Marigolds  false
# 25                            XYZ  false
# 27                          Cooll  false
# 31                       Snowball  false
# 33                        No Idea  false
# 35             SMK Bukit Jelutong  false
# 40                        AlgoMan  false
# 45                 JENNIE FANBOYS  false
# 49                  Rule of Three  false
# 60                         BaoBei  false
# 61                 Steady Bombibi  false
# 71                   Northern LRS  false
# ...

# %%
open = df.loc[df["open"] == "true"]
close = df.loc[df["open"] == "false"]

# %%
open.to_json("open.json", index=False, orient="table")
close.to_json("close.json", index=False, orient="table")

# %%
len(open), len(close)
# Out:
# (83, 31)
